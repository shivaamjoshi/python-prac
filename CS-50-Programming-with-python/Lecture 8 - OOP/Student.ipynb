# %%
# Returns student as tuple, unpacking it

def main():
    name, house = get_student() # student = get_student()
    print(f"{name} from {house}") # print(f"{student[0]} from {student[1]}")

def get_student():
    name = input("Name: ")
    house = input("House: ")
    return name, house #Same can be achieved without unpacking it -> return (name, house)

if __name__ == "__main__":
    main()

# %%
# Defines class a student

class Student:
    # Adds __init__
    def __init__(self, name, house):
        # Adds validation in __init__ using raise
        if not name:
            raise ValueError("Missing name")
        if house not in ["Ghadoli", "Kondli", "Noida"]:
            raise ValueError("Invalid house")
        self.name = name
        self.house = house

def main():
    student = get_student()
    print(f"{student.name} from {student.house}")

def get_student():
    name = input("Name: ")
    house = input("House: ")\
    # Eliminates unneeded variable
    return Student(name, house)

if __name__ == "__main__":
    main()

# %%
# Defines class a student

class Student:
    # Adds __init__
    def __init__(self, name, house):
        # Adds validation in __init__ using raise
        # if not name:
        #     raise ValueError("Missing name")
        # if house not in ["Ghadoli", "Kondli", "Noida"]:
        #     raise ValueError("Invalid house")
        self.name = name
        self.house = house
    
    # Adds __str__
    def __str__(self):
        return f"{self.name} from {self.house}"
    
    # Adds @property for name
    @property
    def name(self):
        return self._name
    
    @name.setter
    def name(self, name):
        if not name:
            raise ValueError("Missing name")
        self ._name = name
    
    # Adds @property for house
    @property
    def house(self):
        return self._house
    
    @house.setter
    def house(self, house):
        if house not in ["Ghadoli", "Kondli", "Noida"]:
            raise ValueError("Invalid house")
        self ._house = house

def main():
    student = get_student()
    # Prints student without __str__ -> <__main__.Student object at 0xff3dc62b0050>
    print(student)
    # print(f"{student.name} from {student.house}")

def get_student():
    name = input("Name: ")
    house = input("House: ")\
    # Eliminates unneeded variable
    return Student(name, house)

if __name__ == "__main__":
    main()
